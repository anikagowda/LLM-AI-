# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# ### Importing the libraries

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
tf.__version__
# Out:
# '2.19.0'

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Preprocessing the Training set

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os, shutil, random

src_base = "/content/drive/MyDrive/deep_learning/dogs_n_cats/training_set"
dst_base = "/content/drive/MyDrive/deep_learning/dogs_n_cats/dataset_small/train"

os.makedirs(dst_base, exist_ok=True)

classes = ['cats', 'dogs']

for cls in classes:
    src_folder = os.path.join(src_base, cls)
    dst_folder = os.path.join(dst_base, cls)
    os.makedirs(dst_folder, exist_ok=True)

    images = os.listdir(src_folder)
    selected_images = random.sample(images, 250)

    for img in selected_images:
        shutil.copy(os.path.join(src_folder, img),
                    os.path.join(dst_folder, img))

# %%
# creating a new folder with 250 images for test data

import os, shutil, random

src_base = "/content/drive/MyDrive/deep_learning/dogs_n_cats/test_set"
dst_base = "/content/drive/MyDrive/deep_learning/dogs_n_cats/dataset_small/test"

os.makedirs(dst_base, exist_ok=True)

classes = ['cats', 'dogs']

for cls in classes:
    src_folder = os.path.join(src_base, cls)
    dst_folder = os.path.join(dst_base, cls)
    os.makedirs(dst_folder, exist_ok=True)

    images = os.listdir(src_folder)
    selected_images = random.sample(images, 250)

    for img in selected_images:
        shutil.copy(os.path.join(src_folder, img),
                    os.path.join(dst_folder, img))

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,            # normalization
                                   shear_range = 0.2,           # Image augmentation parameters
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/deep_learning/dogs_n_cats/dataset_small/train',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 500 images belonging to 2 classes.

# %% [markdown]
# ### Preprocessing the Test set

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/deep_learning/dogs_n_cats/dataset_small/test',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 500 images belonging to 2 classes.

# %% [markdown]
# ## Part 2 - Building the CNN

# %%
cnn = tf.keras.models.Sequential()
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))   # Convolution layer 1
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))
                                          # Pooling layer 1
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))                            # Convolution layer 2
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))                                               # Pooling layer 2
cnn.add(tf.keras.layers.Flatten())                                                                       # Flattening layer
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))                                             # Fully connected layer
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))                                            # Output layer
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ## Part 3 - Training the CNN

# %%
#Compile CNN
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
#Fitting CNN on our training set
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 11s 511ms/step - accuracy: 0.4417 - loss: 0.8285 - val_accuracy: 0.5020 - val_loss: 0.6912
# Epoch 2/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 529ms/step - accuracy: 0.4965 - loss: 0.6926 - val_accuracy: 0.5680 - val_loss: 0.6916
# Epoch 3/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 461ms/step - accuracy: 0.5403 - loss: 0.6910 - val_accuracy: 0.5440 - val_loss: 0.6833
# Epoch 4/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 539ms/step - accuracy: 0.5704 - loss: 0.6865 - val_accuracy: 0.6080 - val_loss: 0.6771
# Epoch 5/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 447ms/step - accuracy: 0.6208 - loss: 0.6678 - val_accuracy: 0.5840 - val_loss: 0.6655
# Epoch 6/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 9s 551ms/step - accuracy: 0.6624 - loss: 0.6409 - val_accuracy: 0.5980 - val_loss: 0.6685
# Epoch 7/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 468ms/step - accuracy: 0.5851 - loss: 0.6647 - val_accuracy: 0.5680 - val_loss: 0.6802
# Epoch 8/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 506ms/step - accuracy: 0.6594 - loss: 0.6325 - val_accuracy: 0.5700 - val_loss: 0.6912
# Epoch 9/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 488ms/step - accuracy: 0.6864 - loss: 0.6183 - val_accuracy: 0.5920 - val_loss: 0.6758
# Epoch 10/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 464ms/step - accuracy: 0.6548 - loss: 0.5922 - val_accuracy: 0.5980 - val_loss: 0.6912
# Epoch 11/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 527ms/step - accuracy: 0.7225 - loss: 0.5549 - val_accuracy: 0.6080 - val_loss: 0.7137
# Epoch 12/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 460ms/step - accuracy: 0.6283 - loss: 0.6190 - val_accuracy: 0.6000 - val_loss: 0.6718
# Epoch 13/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 537ms/step - accuracy: 0.7011 - loss: 0.5744 - val_accuracy: 0.6300 - val_loss: 0.6525
# Epoch 14/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 445ms/step - accuracy: 0.6996 - loss: 0.5628 - val_accuracy: 0.6360 - val_loss: 0.6643
# Epoch 15/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 536ms/step - accuracy: 0.7179 - loss: 0.5311 - val_accuracy: 0.6340 - val_loss: 0.6572
# Epoch 16/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 453ms/step - accuracy: 0.7446 - loss: 0.5187 - val_accuracy: 0.6360 - val_loss: 0.6630
# Epoch 17/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 452ms/step - accuracy: 0.7478 - loss: 0.4978 - val_accuracy: 0.5940 - val_loss: 0.7091
# Epoch 18/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 9s 551ms/step - accuracy: 0.8033 - loss: 0.4397 - val_accuracy: 0.6420 - val_loss: 0.6729
# Epoch 19/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 446ms/step - accuracy: 0.8095 - loss: 0.4353 - val_accuracy: 0.6580 - val_loss: 0.6742
# Epoch 20/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 544ms/step - accuracy: 0.7717 - loss: 0.4819 - val_accuracy: 0.6520 - val_loss: 0.6776
# Epoch 21/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 449ms/step - accuracy: 0.8229 - loss: 0.3974 - val_accuracy: 0.6380 - val_loss: 0.6899
# Epoch 22/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 500ms/step - accuracy: 0.7855 - loss: 0.4280 - val_accuracy: 0.6600 - val_loss: 0.6996
# Epoch 23/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 613ms/step - accuracy: 0.8203 - loss: 0.3809 - val_accuracy: 0.6720 - val_loss: 0.7439
# Epoch 24/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 445ms/step - accuracy: 0.8282 - loss: 0.3849 - val_accuracy: 0.6620 - val_loss: 0.7491
# Epoch 25/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 538ms/step - accuracy: 0.8277 - loss: 0.3521 - val_accuracy: 0.6500 - val_loss: 0.7765

# %% [markdown]
# ## Part 4 - Making a single prediction

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
test_image = image.load_img('/content/drive/MyDrive/deep_learning/dogs_n_cats/single_prediction/cat_or_dog_1.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step

# %%
print(prediction)
# Out:
# dog

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf

train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)  # only rescale for validation/test

training_set = train_datagen.flow_from_directory(
    '/content/drive/MyDrive/deep_learning/dogs_n_cats/dataset_small/train',
    target_size=(64, 64),
    batch_size=32,
    class_mode='binary'
)

test_set = test_datagen.flow_from_directory(
    '/content/drive/MyDrive/deep_learning/dogs_n_cats/dataset_small/test',
    target_size=(64, 64),
    batch_size=32,
    class_mode='binary'
)

cnn = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=[64, 64, 3]),
    tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=128, activation='relu'),
    tf.keras.layers.Dense(units=1, activation='sigmoid')
])


cnn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

cnn.fit(x=training_set, validation_data=test_set, epochs=25)
# Out:
# Found 500 images belonging to 2 classes.
# Found 500 images belonging to 2 classes.
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 524ms/step - accuracy: 0.5433 - loss: 0.7771 - val_accuracy: 0.5000 - val_loss: 0.6897
# Epoch 2/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 9s 549ms/step - accuracy: 0.4958 - loss: 0.6918 - val_accuracy: 0.4980 - val_loss: 0.6881
# Epoch 3/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 470ms/step - accuracy: 0.4945 - loss: 0.6881 - val_accuracy: 0.5060 - val_loss: 0.6827
# Epoch 4/25
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 9s